# %%
Y_tahmin = [0,0,0,1]

# %%
print([Y_tahmin==0,0],[Y_tahmin==0,1])
# Out:
# [False, 0] [False, 1]

# %%
X = [[15,25],
    [25,45],
    [35,55],
    [44,65]
]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X = np.array(X)
Y_tahmin = np.array(Y_tahmin)

# %%
print(X[Y_tahmin==0,0])
print(X[Y_tahmin==0,1])
# Out:
# [15 25 35]
# [25 45 55]

# %%
plt.scatter(X[Y_tahmin==0,0],X[Y_tahmin==0,1],c='red')
plt.scatter(X[Y_tahmin==1,0],X[Y_tahmin==1,1],c='blue')
